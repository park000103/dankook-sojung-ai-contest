# %% [markdown]
# ## 분석에 필요한 library 불러오기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import StratifiedKFold

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, roc_auc_score
from sklearn.metrics import confusion_matrix
from lightgbm import LGBMClassifier

# %% [markdown]
# - 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# - 경로 지정

# %%
import os
os.chdir("/content/gdrive/MyDrive/2022빅콘테스트_데이터분석리그_데이터분석분야_퓨처스부문_데이터셋_220908")

# %% [markdown]
# ## 데이터 불러오기

# %%
train = pd.read_csv("./train_2.csv", encoding = 'cp949',  index_col = 0)
test = pd.read_csv("./test_2.csv", encoding = 'cp949',  index_col = 0)

# %% [markdown]
# - 파생데이터 파일 불러오기

# %%
count_bank = pd.read_csv("./count_bank.csv", encoding = 'cp949',  index_col = 0)
count_prod = pd.read_csv("./count_prod.csv", encoding = 'cp949',  index_col = 0)

# %%
count_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 0 to 61
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   bank_id          62 non-null     int64
#  1   bank_count       62 non-null     int64
#  2   bank_product     62 non-null     int64
#  3   apply_rate_bank  62 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 2.4 KB

# %%
count_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 0 to 167
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      168 non-null    int64
#  1   product_count   168 non-null    int64
#  2   pro_apply_rate  168 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 5.2 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3255194 entries, 0 to 3255084
# Data columns (total 28 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   application_id                       int64
#  1   user_id                              int64
#  2   insert_time                          object
#  3   credit_score                         float64
#  4   yearly_income                        float64
#  5   income_type                          object
#  6   company_enter_month                  object
#  7   employment_type                      object
#  8   houseown_type                        object
#  9   desired_amount                       float64
#  10  purpose                              object
#  11  personal_rehabilitation_yn           float64
#  12  personal_rehabilitation_complete_yn  int64
#  13  existing_loan_cnt                    float64
#  14  existing_loan_amt                    float64
#  15  NA_count                             int64
#  16  gender                               float64
#  17  birth_year                           float64
#  18  age                                  float64
#  19  company_month                        float64
#  20  lotloan                              int64
#  21  loanapply_insert_time                object
#  22  bank_id                              int64
#  23  product_id                           int64
#  24  loan_limit                           float64
#  25  loan_rate                            float64
#  26  is_applied                           float64
#  27  pre_bank_rate                        float64
# dtypes: float64(14), int64(7), object(7)
# memory usage: 720.2+ MB

# %% [markdown]
# - train data + 파생변수 데이터

# %%
train = pd.merge(count_bank, train, on='bank_id', how='left')
train = pd.merge(count_prod, train, on='product_id', how='left')

# %% [markdown]
# - test data + 파생변수 데이터

# %%
test = pd.merge(count_bank, test, on='bank_id', how='left')
test = pd.merge(count_prod, test, on='product_id', how='left')

# %%
train.shape
# Out:
# (10263722, 36)

# %%
test.shape
# Out:
# (3242644, 33)

# %% [markdown]
# - desired_rate 파생변수 생성

# %%
train['desired_rate'] = round(train['loan_limit']/10,0) / train['desired_amount']
test['desired_rate'] = round(test['loan_limit']/10,0) / test['desired_amount']

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3242644 entries, 0 to 3242643
# Data columns (total 34 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   product_id                           int64
#  1   product_count                        int64
#  2   pro_apply_rate                       float64
#  3   bank_id                              float64
#  4   bank_count                           float64
#  5   bank_product                         float64
#  6   apply_rate_bank                      float64
#  7   application_id                       float64
#  8   user_id                              float64
#  9   insert_time                          object
#  10  credit_score                         float64
#  11  yearly_income                        float64
#  12  income_type                          object
#  13  company_enter_month                  object
#  14  employment_type                      object
#  15  houseown_type                        object
#  16  desired_amount                       float64
#  17  purpose                              object
#  18  personal_rehabilitation_yn           float64
#  19  personal_rehabilitation_complete_yn  float64
#  20  existing_loan_cnt                    float64
#  21  existing_loan_amt                    float64
#  22  NA_count                             float64
#  23  gender                               float64
#  24  birth_year                           float64
#  25  age                                  float64
#  26  company_month                        float64
#  27  lotloan                              float64
#  28  loanapply_insert_time                object
#  29  loan_limit                           float64
#  30  loan_rate                            float64
#  31  is_applied                           float64
#  32  pre_bank_rate                        float64
#  33  desired_rate                         float64
# dtypes: float64(25), int64(2), object(7)
# memory usage: 865.9+ MB

# %% [markdown]
# # 예측 알고리즘 만들기

# %%
train1 = train[['credit_score',  'existing_loan_cnt', 'existing_loan_amt', 'NA_count', 'age', 'company_month',
                'lotloan', 'loan_limit', 'desired_rate', 'loan_rate', 'pre_bank_rate', 'is_applied', 'bank_product', 'apply_rate_bank', 'pro_apply_rate']]

# %%
test1 = test[['credit_score',  'existing_loan_cnt', 'existing_loan_amt', 'NA_count', 'age', 'company_month',
                'lotloan', 'loan_limit', 'desired_rate', 'loan_rate', 'pre_bank_rate', 'bank_product', 'apply_rate_bank', 'pro_apply_rate']]

# %%
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10263722 entries, 0 to 10263721
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   credit_score       float64
#  1   existing_loan_cnt  float64
#  2   existing_loan_amt  float64
#  3   NA_count           float64
#  4   age                float64
#  5   company_month      float64
#  6   lotloan            float64
#  7   loan_limit         float64
#  8   desired_rate       float64
#  9   loan_rate          float64
#  10  pre_bank_rate      float64
#  11  bank_product       int64
#  12  apply_rate_bank    float64
#  13  pro_apply_rate     float64
# dtypes: float64(13), int64(1)
# memory usage: 1.4 GB

# %%
train1['lotloan'] = train1['lotloan'].astype('category')
train1['lotloan'] = train1['lotloan'].astype('category')

test1['lotloan'] = test1['lotloan'].astype('category')
test1['lotloan'] = test1['lotloan'].astype('category')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# - StratifiedKFold 교차검증하기

# %%
x = train1.drop(['is_applied'], axis=1)
y = train1['is_applied']

# %%
skf = StratifiedKFold(n_splits=5)

for train_idx, test_idx in skf.split(x, y):
  X_train = x.iloc[train_idx]
  X_test = x.iloc[test_idx]
  y_train, y_test = y[train_idx], y[test_idx]


  model = LGBMClassifier(n_estimators=300)
  lgb_eval =[(X_test, y_test)]
  model.fit(X_train,y_train,
                eval_set=lgb_eval,
                eval_metric='logloss',
                verbose=True,
                early_stopping_rounds=100)

  preds = model.predict(X_test)
  print(f1_score(y_test, preds))
# Out:
# [1]	valid_0's binary_logloss: 0.200426	valid_0's binary_logloss: 0.200426
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.193735	valid_0's binary_logloss: 0.193735
# [3]	valid_0's binary_logloss: 0.189364	valid_0's binary_logloss: 0.189364
# [4]	valid_0's binary_logloss: 0.185321	valid_0's binary_logloss: 0.185321
# [5]	valid_0's binary_logloss: 0.182339	valid_0's binary_logloss: 0.182339
# [6]	valid_0's binary_logloss: 0.180319	valid_0's binary_logloss: 0.180319
# [7]	valid_0's binary_logloss: 0.178881	valid_0's binary_logloss: 0.178881
# [8]	valid_0's binary_logloss: 0.17731	valid_0's binary_logloss: 0.17731
# [9]	valid_0's binary_logloss: 0.175427	valid_0's binary_logloss: 0.175427
# [10]	valid_0's binary_logloss: 0.174066	valid_0's binary_logloss: 0.174066
# [11]	valid_0's binary_logloss: 0.173072	valid_0's binary_logloss: 0.173072
# [12]	valid_0's binary_logloss: 0.171845	valid_0's binary_logloss: 0.171845
# [13]	valid_0's binary_logloss: 0.170684	valid_0's binary_logloss: 0.170684
# [14]	valid_0's binary_logloss: 0.169691	valid_0's binary_logloss: 0.169691
# [15]	valid_0's binary_logloss: 0.16871	valid_0's binary_logloss: 0.16871
# [16]	valid_0's binary_logloss: 0.168156	valid_0's binary_logloss: 0.168156
# [17]	valid_0's binary_logloss: 0.167326	valid_0's binary_logloss: 0.167326
# [18]	valid_0's binary_logloss: 0.166589	valid_0's binary_logloss: 0.166589
# [19]	valid_0's binary_logloss: 0.165968	valid_0's binary_logloss: 0.165968
# [20]	valid_0's binary_logloss: 0.166198	valid_0's binary_logloss: 0.166198
# [21]	valid_0's binary_logloss: 0.165747	valid_0's binary_logloss: 0.165747
# [22]	valid_0's binary_logloss: 0.16533	valid_0's binary_logloss: 0.16533
# [23]	valid_0's binary_logloss: 0.164971	valid_0's binary_logloss: 0.164971
# [24]	valid_0's binary_logloss: 0.164497	valid_0's binary_logloss: 0.164497
# [25]	valid_0's binary_logloss: 0.164862	valid_0's binary_logloss: 0.164862
# [26]	valid_0's binary_logloss: 0.164464	valid_0's binary_logloss: 0.164464
# [27]	valid_0's binary_logloss: 0.164118	valid_0's binary_logloss: 0.164118
# [28]	valid_0's binary_logloss: 0.163869	valid_0's binary_logloss: 0.163869
# [29]	valid_0's binary_logloss: 0.163635	valid_0's binary_logloss: 0.163635
# [30]	valid_0's binary_logloss: 0.163381	valid_0's binary_logloss: 0.163381
# [31]	valid_0's binary_logloss: 0.163171	valid_0's binary_logloss: 0.163171
# [32]	valid_0's binary_logloss: 0.163015	valid_0's binary_logloss: 0.163015
# [33]	valid_0's binary_logloss: 0.162889	valid_0's binary_logloss: 0.162889
# [34]	valid_0's binary_logloss: 0.162802	valid_0's binary_logloss: 0.162802
# [35]	valid_0's binary_logloss: 0.162762	valid_0's binary_logloss: 0.162762
# [36]	valid_0's binary_logloss: 0.162915	valid_0's binary_logloss: 0.162915
# [37]	valid_0's binary_logloss: 0.162854	valid_0's binary_logloss: 0.162854
# [38]	valid_0's binary_logloss: 0.162724	valid_0's binary_logloss: 0.162724
# [39]	valid_0's binary_logloss: 0.162609	valid_0's binary_logloss: 0.162609
# [40]	valid_0's binary_logloss: 0.162753	valid_0's binary_logloss: 0.162753
# [41]	valid_0's binary_logloss: 0.16304	valid_0's binary_logloss: 0.16304
# [42]	valid_0's binary_logloss: 0.16301	valid_0's binary_logloss: 0.16301
# [43]	valid_0's binary_logloss: 0.162979	valid_0's binary_logloss: 0.162979
# [44]	valid_0's binary_logloss: 0.16331	valid_0's binary_logloss: 0.16331
# [45]	valid_0's binary_logloss: 0.163439	valid_0's binary_logloss: 0.163439
# [46]	valid_0's binary_logloss: 0.163419	valid_0's binary_logloss: 0.163419
# [47]	valid_0's binary_logloss: 0.163567	valid_0's binary_logloss: 0.163567
# [48]	valid_0's binary_logloss: 0.163998	valid_0's binary_logloss: 0.163998
# [49]	valid_0's binary_logloss: 0.164133	valid_0's binary_logloss: 0.164133
# [50]	valid_0's binary_logloss: 0.164099	valid_0's binary_logloss: 0.164099
# [51]	valid_0's binary_logloss: 0.164043	valid_0's binary_logloss: 0.164043
# [52]	valid_0's binary_logloss: 0.163985	valid_0's binary_logloss: 0.163985
# [53]	valid_0's binary_logloss: 0.164533	valid_0's binary_logloss: 0.164533
# [54]	valid_0's binary_logloss: 0.16448	valid_0's binary_logloss: 0.16448
# [55]	valid_0's binary_logloss: 0.164501	valid_0's binary_logloss: 0.164501
# [56]	valid_0's binary_logloss: 0.165178	valid_0's binary_logloss: 0.165178
# [57]	valid_0's binary_logloss: 0.165319	valid_0's binary_logloss: 0.165319
# [58]	valid_0's binary_logloss: 0.165309	valid_0's binary_logloss: 0.165309
# [59]	valid_0's binary_logloss: 0.16526	valid_0's binary_logloss: 0.16526
# [60]	valid_0's binary_logloss: 0.165451	valid_0's binary_logloss: 0.165451
# [61]	valid_0's binary_logloss: 0.166108	valid_0's binary_logloss: 0.166108
# [62]	valid_0's binary_logloss: 0.166063	valid_0's binary_logloss: 0.166063
# [63]	valid_0's binary_logloss: 0.166034	valid_0's binary_logloss: 0.166034
# [64]	valid_0's binary_logloss: 0.166115	valid_0's binary_logloss: 0.166115
# [65]	valid_0's binary_logloss: 0.166083	valid_0's binary_logloss: 0.166083
# [66]	valid_0's binary_logloss: 0.166095	valid_0's binary_logloss: 0.166095
# [67]	valid_0's binary_logloss: 0.166072	valid_0's binary_logloss: 0.166072
# [68]	valid_0's binary_logloss: 0.166741	valid_0's binary_logloss: 0.166741
# [69]	valid_0's binary_logloss: 0.166783	valid_0's binary_logloss: 0.166783
# [70]	valid_0's binary_logloss: 0.16675	valid_0's binary_logloss: 0.16675
# [71]	valid_0's binary_logloss: 0.166725	valid_0's binary_logloss: 0.166725
# [72]	valid_0's binary_logloss: 0.167519	valid_0's binary_logloss: 0.167519
# [73]	valid_0's binary_logloss: 0.167516	valid_0's binary_logloss: 0.167516
# [74]	valid_0's binary_logloss: 0.167533	valid_0's binary_logloss: 0.167533
# [75]	valid_0's binary_logloss: 0.167548	valid_0's binary_logloss: 0.167548
# [76]	valid_0's binary_logloss: 0.167573	valid_0's binary_logloss: 0.167573
# [77]	valid_0's binary_logloss: 0.167583	valid_0's binary_logloss: 0.167583
# [78]	valid_0's binary_logloss: 0.167594	valid_0's binary_logloss: 0.167594
# [79]	valid_0's binary_logloss: 0.167623	valid_0's binary_logloss: 0.167623
# [80]	valid_0's binary_logloss: 0.167644	valid_0's binary_logloss: 0.167644
# [81]	valid_0's binary_logloss: 0.168272	valid_0's binary_logloss: 0.168272
# [82]	valid_0's binary_logloss: 0.168737	valid_0's binary_logloss: 0.168737
# [83]	valid_0's binary_logloss: 0.168731	valid_0's binary_logloss: 0.168731
# [84]	valid_0's binary_logloss: 0.168752	valid_0's binary_logloss: 0.168752
# [85]	valid_0's binary_logloss: 0.168726	valid_0's binary_logloss: 0.168726
# [86]	valid_0's binary_logloss: 0.168718	valid_0's binary_logloss: 0.168718
# [87]	valid_0's binary_logloss: 0.169565	valid_0's binary_logloss: 0.169565
# [88]	valid_0's binary_logloss: 0.169547	valid_0's binary_logloss: 0.169547
# [89]	valid_0's binary_logloss: 0.169612	valid_0's binary_logloss: 0.169612
# [90]	valid_0's binary_logloss: 0.169644	valid_0's binary_logloss: 0.169644
# [91]	valid_0's binary_logloss: 0.169644	valid_0's binary_logloss: 0.169644
# [92]	valid_0's binary_logloss: 0.170306	valid_0's binary_logloss: 0.170306
# [93]	valid_0's binary_logloss: 0.170302	valid_0's binary_logloss: 0.170302
# [94]	valid_0's binary_logloss: 0.170309	valid_0's binary_logloss: 0.170309
# [95]	valid_0's binary_logloss: 0.170299	valid_0's binary_logloss: 0.170299
# [96]	valid_0's binary_logloss: 0.170298	valid_0's binary_logloss: 0.170298
# [97]	valid_0's binary_logloss: 0.171074	valid_0's binary_logloss: 0.171074
# [98]	valid_0's binary_logloss: 0.171227	valid_0's binary_logloss: 0.171227
# [99]	valid_0's binary_logloss: 0.171214	valid_0's binary_logloss: 0.171214
# [100]	valid_0's binary_logloss: 0.171266	valid_0's binary_logloss: 0.171266
# [101]	valid_0's binary_logloss: 0.171308	valid_0's binary_logloss: 0.171308
# [102]	valid_0's binary_logloss: 0.171308	valid_0's binary_logloss: 0.171308
# [103]	valid_0's binary_logloss: 0.171287	valid_0's binary_logloss: 0.171287
# [104]	valid_0's binary_logloss: 0.172001	valid_0's binary_logloss: 0.172001
# [105]	valid_0's binary_logloss: 0.171989	valid_0's binary_logloss: 0.171989
# [106]	valid_0's binary_logloss: 0.172011	valid_0's binary_logloss: 0.172011
# [107]	valid_0's binary_logloss: 0.172021	valid_0's binary_logloss: 0.172021
# [108]	valid_0's binary_logloss: 0.17202	valid_0's binary_logloss: 0.17202
# [109]	valid_0's binary_logloss: 0.172442	valid_0's binary_logloss: 0.172442
# [110]	valid_0's binary_logloss: 0.172484	valid_0's binary_logloss: 0.172484
# [111]	valid_0's binary_logloss: 0.17256	valid_0's binary_logloss: 0.17256
# [112]	valid_0's binary_logloss: 0.172555	valid_0's binary_logloss: 0.172555
# [113]	valid_0's binary_logloss: 0.172539	valid_0's binary_logloss: 0.172539
# [114]	valid_0's binary_logloss: 0.172516	valid_0's binary_logloss: 0.172516
# [115]	valid_0's binary_logloss: 0.172513	valid_0's binary_logloss: 0.172513
# [116]	valid_0's binary_logloss: 0.172506	valid_0's binary_logloss: 0.172506
# [117]	valid_0's binary_logloss: 0.172585	valid_0's binary_logloss: 0.172585
# [118]	valid_0's binary_logloss: 0.172656	valid_0's binary_logloss: 0.172656
# [119]	valid_0's binary_logloss: 0.172667	valid_0's binary_logloss: 0.172667
# [120]	valid_0's binary_logloss: 0.172699	valid_0's binary_logloss: 0.172699
# [121]	valid_0's binary_logloss: 0.172701	valid_0's binary_logloss: 0.172701
# [122]	valid_0's binary_logloss: 0.172821	valid_0's binary_logloss: 0.172821
# [123]	valid_0's binary_logloss: 0.172817	valid_0's binary_logloss: 0.172817
# [124]	valid_0's binary_logloss: 0.17283	valid_0's binary_logloss: 0.17283
# [125]	valid_0's binary_logloss: 0.17282	valid_0's binary_logloss: 0.17282
# [126]	valid_0's binary_logloss: 0.172811	valid_0's binary_logloss: 0.172811
# [127]	valid_0's binary_logloss: 0.172812	valid_0's binary_logloss: 0.172812
# [128]	valid_0's binary_logloss: 0.172833	valid_0's binary_logloss: 0.172833
# [129]	valid_0's binary_logloss: 0.172813	valid_0's binary_logloss: 0.172813
# [130]	valid_0's binary_logloss: 0.172807	valid_0's binary_logloss: 0.172807
# [131]	valid_0's binary_logloss: 0.172892	valid_0's binary_logloss: 0.172892
# [132]	valid_0's binary_logloss: 0.172893	valid_0's binary_logloss: 0.172893
# [133]	valid_0's binary_logloss: 0.172889	valid_0's binary_logloss: 0.172889
# [134]	valid_0's binary_logloss: 0.172902	valid_0's binary_logloss: 0.172902
# [135]	valid_0's binary_logloss: 0.172909	valid_0's binary_logloss: 0.172909
# [136]	valid_0's binary_logloss: 0.172926	valid_0's binary_logloss: 0.172926
# [137]	valid_0's binary_logloss: 0.172926	valid_0's binary_logloss: 0.172926
# [138]	valid_0's binary_logloss: 0.172917	valid_0's binary_logloss: 0.172917
# [139]	valid_0's binary_logloss: 0.172934	valid_0's binary_logloss: 0.172934
# Early stopping, best iteration is:
# [39]	valid_0's binary_logloss: 0.162609	valid_0's binary_logloss: 0.162609
# 0.023721772946219452
# [1]	valid_0's binary_logloss: 0.205893	valid_0's binary_logloss: 0.205893
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.202695	valid_0's binary_logloss: 0.202695
# [3]	valid_0's binary_logloss: 0.201996	valid_0's binary_logloss: 0.201996
# [4]	valid_0's binary_logloss: 0.204756	valid_0's binary_logloss: 0.204756
# [5]	valid_0's binary_logloss: 0.204665	valid_0's binary_logloss: 0.204665
# [6]	valid_0's binary_logloss: 0.204015	valid_0's binary_logloss: 0.204015
# [7]	valid_0's binary_logloss: 0.20461	valid_0's binary_logloss: 0.20461
# [8]	valid_0's binary_logloss: 0.204511	valid_0's binary_logloss: 0.204511
# [9]	valid_0's binary_logloss: 0.207584	valid_0's binary_logloss: 0.207584
# [10]	valid_0's binary_logloss: 0.206564	valid_0's binary_logloss: 0.206564
# [11]	valid_0's binary_logloss: 0.206472	valid_0's binary_logloss: 0.206472
# [12]	valid_0's binary_logloss: 0.206674	valid_0's binary_logloss: 0.206674
# [13]	valid_0's binary_logloss: 0.206918	valid_0's binary_logloss: 0.206918
# [14]	valid_0's binary_logloss: 0.211738	valid_0's binary_logloss: 0.211738
# [15]	valid_0's binary_logloss: 0.212959	valid_0's binary_logloss: 0.212959
# [16]	valid_0's binary_logloss: 0.213617	valid_0's binary_logloss: 0.213617
# [17]	valid_0's binary_logloss: 0.214114	valid_0's binary_logloss: 0.214114
# [18]	valid_0's binary_logloss: 0.214698	valid_0's binary_logloss: 0.214698
# [19]	valid_0's binary_logloss: 0.215333	valid_0's binary_logloss: 0.215333
# [20]	valid_0's binary_logloss: 0.216694	valid_0's binary_logloss: 0.216694
# [21]	valid_0's binary_logloss: 0.217201	valid_0's binary_logloss: 0.217201
# [22]	valid_0's binary_logloss: 0.223159	valid_0's binary_logloss: 0.223159
# [23]	valid_0's binary_logloss: 0.224043	valid_0's binary_logloss: 0.224043
# [24]	valid_0's binary_logloss: 0.228077	valid_0's binary_logloss: 0.228077
# [25]	valid_0's binary_logloss: 0.227868	valid_0's binary_logloss: 0.227868
# [26]	valid_0's binary_logloss: 0.23055	valid_0's binary_logloss: 0.23055
# [27]	valid_0's binary_logloss: 0.23274	valid_0's binary_logloss: 0.23274
# [28]	valid_0's binary_logloss: 0.232743	valid_0's binary_logloss: 0.232743
# [29]	valid_0's binary_logloss: 0.23335	valid_0's binary_logloss: 0.23335
# [30]	valid_0's binary_logloss: 0.241025	valid_0's binary_logloss: 0.241025
# [31]	valid_0's binary_logloss: 0.241244	valid_0's binary_logloss: 0.241244
# [32]	valid_0's binary_logloss: 0.244881	valid_0's binary_logloss: 0.244881
# [33]	valid_0's binary_logloss: 0.245421	valid_0's binary_logloss: 0.245421
# [34]	valid_0's binary_logloss: 0.249446	valid_0's binary_logloss: 0.249446
# [35]	valid_0's binary_logloss: 0.249901	valid_0's binary_logloss: 0.249901
# [36]	valid_0's binary_logloss: 0.250049	valid_0's binary_logloss: 0.250049
# [37]	valid_0's binary_logloss: 0.250206	valid_0's binary_logloss: 0.250206
# [38]	valid_0's binary_logloss: 0.251359	valid_0's binary_logloss: 0.251359
# [39]	valid_0's binary_logloss: 0.253545	valid_0's binary_logloss: 0.253545
# [40]	valid_0's binary_logloss: 0.253436	valid_0's binary_logloss: 0.253436
# [41]	valid_0's binary_logloss: 0.255074	valid_0's binary_logloss: 0.255074
# [42]	valid_0's binary_logloss: 0.260893	valid_0's binary_logloss: 0.260893
# [43]	valid_0's binary_logloss: 0.260981	valid_0's binary_logloss: 0.260981
# [44]	valid_0's binary_logloss: 0.261166	valid_0's binary_logloss: 0.261166
# [45]	valid_0's binary_logloss: 0.265707	valid_0's binary_logloss: 0.265707
# [46]	valid_0's binary_logloss: 0.266046	valid_0's binary_logloss: 0.266046
# [47]	valid_0's binary_logloss: 0.26766	valid_0's binary_logloss: 0.26766
# [48]	valid_0's binary_logloss: 0.269434	valid_0's binary_logloss: 0.269434
# [49]	valid_0's binary_logloss: 0.271796	valid_0's binary_logloss: 0.271796
# [50]	valid_0's binary_logloss: 0.272392	valid_0's binary_logloss: 0.272392
# [51]	valid_0's binary_logloss: 0.274462	valid_0's binary_logloss: 0.274462
# [52]	valid_0's binary_logloss: 0.275375	valid_0's binary_logloss: 0.275375
# [53]	valid_0's binary_logloss: 0.275286	valid_0's binary_logloss: 0.275286
# [54]	valid_0's binary_logloss: 0.276018	valid_0's binary_logloss: 0.276018
# [55]	valid_0's binary_logloss: 0.276035	valid_0's binary_logloss: 0.276035
# [56]	valid_0's binary_logloss: 0.277885	valid_0's binary_logloss: 0.277885
# [57]	valid_0's binary_logloss: 0.279061	valid_0's binary_logloss: 0.279061
# [58]	valid_0's binary_logloss: 0.281301	valid_0's binary_logloss: 0.281301
# [59]	valid_0's binary_logloss: 0.281742	valid_0's binary_logloss: 0.281742
# [60]	valid_0's binary_logloss: 0.28156	valid_0's binary_logloss: 0.28156
# [61]	valid_0's binary_logloss: 0.282426	valid_0's binary_logloss: 0.282426
# [62]	valid_0's binary_logloss: 0.292816	valid_0's binary_logloss: 0.292816
# [63]	valid_0's binary_logloss: 0.301882	valid_0's binary_logloss: 0.301882
# [64]	valid_0's binary_logloss: 0.305776	valid_0's binary_logloss: 0.305776
# [65]	valid_0's binary_logloss: 0.305634	valid_0's binary_logloss: 0.305634
# [66]	valid_0's binary_logloss: 0.306149	valid_0's binary_logloss: 0.306149
# [67]	valid_0's binary_logloss: 0.309398	valid_0's binary_logloss: 0.309398
# [68]	valid_0's binary_logloss: 0.309335	valid_0's binary_logloss: 0.309335
# [69]	valid_0's binary_logloss: 0.309194	valid_0's binary_logloss: 0.309194
# [70]	valid_0's binary_logloss: 0.309417	valid_0's binary_logloss: 0.309417
# [71]	valid_0's binary_logloss: 0.328187	valid_0's binary_logloss: 0.328187
# [72]	valid_0's binary_logloss: 0.329123	valid_0's binary_logloss: 0.329123
# [73]	valid_0's binary_logloss: 0.3316	valid_0's binary_logloss: 0.3316
# [74]	valid_0's binary_logloss: 0.331698	valid_0's binary_logloss: 0.331698
# [75]	valid_0's binary_logloss: 0.338589	valid_0's binary_logloss: 0.338589
# [76]	valid_0's binary_logloss: 0.33907	valid_0's binary_logloss: 0.33907
# [77]	valid_0's binary_logloss: 0.339526	valid_0's binary_logloss: 0.339526
# [78]	valid_0's binary_logloss: 0.349726	valid_0's binary_logloss: 0.349726
# [79]	valid_0's binary_logloss: 0.356838	valid_0's binary_logloss: 0.356838
# [80]	valid_0's binary_logloss: 0.356656	valid_0's binary_logloss: 0.356656
# [81]	valid_0's binary_logloss: 0.3577	valid_0's binary_logloss: 0.3577
# [82]	valid_0's binary_logloss: 0.364968	valid_0's binary_logloss: 0.364968
# [83]	valid_0's binary_logloss: 0.365678	valid_0's binary_logloss: 0.365678
# [84]	valid_0's binary_logloss: 0.365533	valid_0's binary_logloss: 0.365533
# [85]	valid_0's binary_logloss: 0.366572	valid_0's binary_logloss: 0.366572
# [86]	valid_0's binary_logloss: 0.380332	valid_0's binary_logloss: 0.380332
# [87]	valid_0's binary_logloss: 0.380176	valid_0's binary_logloss: 0.380176
# [88]	valid_0's binary_logloss: 0.381843	valid_0's binary_logloss: 0.381843
# [89]	valid_0's binary_logloss: 0.382749	valid_0's binary_logloss: 0.382749
# [90]	valid_0's binary_logloss: 0.38266	valid_0's binary_logloss: 0.38266
# [91]	valid_0's binary_logloss: 0.382693	valid_0's binary_logloss: 0.382693
# [92]	valid_0's binary_logloss: 0.382873	valid_0's binary_logloss: 0.382873
# [93]	valid_0's binary_logloss: 0.383586	valid_0's binary_logloss: 0.383586
# [94]	valid_0's binary_logloss: 0.391105	valid_0's binary_logloss: 0.391105
# [95]	valid_0's binary_logloss: 0.3912	valid_0's binary_logloss: 0.3912
# [96]	valid_0's binary_logloss: 0.392071	valid_0's binary_logloss: 0.392071
# [97]	valid_0's binary_logloss: 0.39232	valid_0's binary_logloss: 0.39232
# [98]	valid_0's binary_logloss: 0.393138	valid_0's binary_logloss: 0.393138
# [99]	valid_0's binary_logloss: 0.393837	valid_0's binary_logloss: 0.393837
# [100]	valid_0's binary_logloss: 0.39374	valid_0's binary_logloss: 0.39374
# [101]	valid_0's binary_logloss: 0.393851	valid_0's binary_logloss: 0.393851
# [102]	valid_0's binary_logloss: 0.393839	valid_0's binary_logloss: 0.393839
# [103]	valid_0's binary_logloss: 0.400679	valid_0's binary_logloss: 0.400679
# Early stopping, best iteration is:
# [3]	valid_0's binary_logloss: 0.201996	valid_0's binary_logloss: 0.201996
# 0.0
# [1]	valid_0's binary_logloss: 0.214418	valid_0's binary_logloss: 0.214418
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.217878	valid_0's binary_logloss: 0.217878
# [3]	valid_0's binary_logloss: 0.218475	valid_0's binary_logloss: 0.218475
# [4]	valid_0's binary_logloss: 0.219925	valid_0's binary_logloss: 0.219925
# [5]	valid_0's binary_logloss: 0.223352	valid_0's binary_logloss: 0.223352
# [6]	valid_0's binary_logloss: 0.22574	valid_0's binary_logloss: 0.22574
# [7]	valid_0's binary_logloss: 0.229147	valid_0's binary_logloss: 0.229147
# [8]	valid_0's binary_logloss: 0.233437	valid_0's binary_logloss: 0.233437
# [9]	valid_0's binary_logloss: 0.23415	valid_0's binary_logloss: 0.23415
# [10]	valid_0's binary_logloss: 0.24059	valid_0's binary_logloss: 0.24059
# [11]	valid_0's binary_logloss: 0.246424	valid_0's binary_logloss: 0.246424
# [12]	valid_0's binary_logloss: 0.247867	valid_0's binary_logloss: 0.247867
# [13]	valid_0's binary_logloss: 0.253172	valid_0's binary_logloss: 0.253172
# [14]	valid_0's binary_logloss: 0.258043	valid_0's binary_logloss: 0.258043
# [15]	valid_0's binary_logloss: 0.261624	valid_0's binary_logloss: 0.261624
# [16]	valid_0's binary_logloss: 0.264084	valid_0's binary_logloss: 0.264084
# [17]	valid_0's binary_logloss: 0.268389	valid_0's binary_logloss: 0.268389
# [18]	valid_0's binary_logloss: 0.271368	valid_0's binary_logloss: 0.271368
# [19]	valid_0's binary_logloss: 0.273955	valid_0's binary_logloss: 0.273955
# [20]	valid_0's binary_logloss: 0.278605	valid_0's binary_logloss: 0.278605
# [21]	valid_0's binary_logloss: 0.281726	valid_0's binary_logloss: 0.281726
# [22]	valid_0's binary_logloss: 0.287603	valid_0's binary_logloss: 0.287603
# [23]	valid_0's binary_logloss: 0.292173	valid_0's binary_logloss: 0.292173
# [24]	valid_0's binary_logloss: 0.294447	valid_0's binary_logloss: 0.294447
# [25]	valid_0's binary_logloss: 0.29737	valid_0's binary_logloss: 0.29737
# [26]	valid_0's binary_logloss: 0.31324	valid_0's binary_logloss: 0.31324
# [27]	valid_0's binary_logloss: 0.323211	valid_0's binary_logloss: 0.323211
# [28]	valid_0's binary_logloss: 0.324181	valid_0's binary_logloss: 0.324181
# [29]	valid_0's binary_logloss: 0.330754	valid_0's binary_logloss: 0.330754
# [30]	valid_0's binary_logloss: 0.337672	valid_0's binary_logloss: 0.337672
# [31]	valid_0's binary_logloss: 0.345606	valid_0's binary_logloss: 0.345606
# [32]	valid_0's binary_logloss: 0.353106	valid_0's binary_logloss: 0.353106
# [33]	valid_0's binary_logloss: 0.355585	valid_0's binary_logloss: 0.355585
# [34]	valid_0's binary_logloss: 0.356516	valid_0's binary_logloss: 0.356516
# [35]	valid_0's binary_logloss: 0.358378	valid_0's binary_logloss: 0.358378
# [36]	valid_0's binary_logloss: 0.380797	valid_0's binary_logloss: 0.380797
# [37]	valid_0's binary_logloss: 0.384992	valid_0's binary_logloss: 0.384992
# [38]	valid_0's binary_logloss: 0.390598	valid_0's binary_logloss: 0.390598
# [39]	valid_0's binary_logloss: 0.392158	valid_0's binary_logloss: 0.392158
# [40]	valid_0's binary_logloss: 0.395126	valid_0's binary_logloss: 0.395126
# [41]	valid_0's binary_logloss: 0.397667	valid_0's binary_logloss: 0.397667
# [42]	valid_0's binary_logloss: 0.399135	valid_0's binary_logloss: 0.399135
# [43]	valid_0's binary_logloss: 0.400564	valid_0's binary_logloss: 0.400564
# [44]	valid_0's binary_logloss: 0.40204	valid_0's binary_logloss: 0.40204
# [45]	valid_0's binary_logloss: 0.404628	valid_0's binary_logloss: 0.404628
# [46]	valid_0's binary_logloss: 0.409508	valid_0's binary_logloss: 0.409508
# [47]	valid_0's binary_logloss: 0.410054	valid_0's binary_logloss: 0.410054
# [48]	valid_0's binary_logloss: 0.410899	valid_0's binary_logloss: 0.410899
# [49]	valid_0's binary_logloss: 0.410901	valid_0's binary_logloss: 0.410901
# [50]	valid_0's binary_logloss: 0.412593	valid_0's binary_logloss: 0.412593
# [51]	valid_0's binary_logloss: 0.417793	valid_0's binary_logloss: 0.417793
# [52]	valid_0's binary_logloss: 0.421063	valid_0's binary_logloss: 0.421063
# [53]	valid_0's binary_logloss: 0.422143	valid_0's binary_logloss: 0.422143
# [54]	valid_0's binary_logloss: 0.457858	valid_0's binary_logloss: 0.457858
# [55]	valid_0's binary_logloss: 0.465909	valid_0's binary_logloss: 0.465909
# [56]	valid_0's binary_logloss: 0.466537	valid_0's binary_logloss: 0.466537
# [57]	valid_0's binary_logloss: 0.477204	valid_0's binary_logloss: 0.477204
# [58]	valid_0's binary_logloss: 0.476877	valid_0's binary_logloss: 0.476877
# [59]	valid_0's binary_logloss: 0.47904	valid_0's binary_logloss: 0.47904
# [60]	valid_0's binary_logloss: 0.479445	valid_0's binary_logloss: 0.479445
# [61]	valid_0's binary_logloss: 0.478958	valid_0's binary_logloss: 0.478958
# [62]	valid_0's binary_logloss: 0.485291	valid_0's binary_logloss: 0.485291
# [63]	valid_0's binary_logloss: 0.500705	valid_0's binary_logloss: 0.500705
# [64]	valid_0's binary_logloss: 0.500366	valid_0's binary_logloss: 0.500366
# [65]	valid_0's binary_logloss: 0.500082	valid_0's binary_logloss: 0.500082
# [66]	valid_0's binary_logloss: 0.502858	valid_0's binary_logloss: 0.502858
# [67]	valid_0's binary_logloss: 0.503656	valid_0's binary_logloss: 0.503656
# [68]	valid_0's binary_logloss: 0.510529	valid_0's binary_logloss: 0.510529
# [69]	valid_0's binary_logloss: 0.512154	valid_0's binary_logloss: 0.512154
# [70]	valid_0's binary_logloss: 0.51243	valid_0's binary_logloss: 0.51243
# [71]	valid_0's binary_logloss: 0.515836	valid_0's binary_logloss: 0.515836
# [72]	valid_0's binary_logloss: 0.528072	valid_0's binary_logloss: 0.528072
# [73]	valid_0's binary_logloss: 0.534831	valid_0's binary_logloss: 0.534831
# [74]	valid_0's binary_logloss: 0.538613	valid_0's binary_logloss: 0.538613
# [75]	valid_0's binary_logloss: 0.543026	valid_0's binary_logloss: 0.543026
# [76]	valid_0's binary_logloss: 0.542816	valid_0's binary_logloss: 0.542816
# [77]	valid_0's binary_logloss: 0.543532	valid_0's binary_logloss: 0.543532
# [78]	valid_0's binary_logloss: 0.55077	valid_0's binary_logloss: 0.55077
# [79]	valid_0's binary_logloss: 0.551922	valid_0's binary_logloss: 0.551922
# [80]	valid_0's binary_logloss: 0.562132	valid_0's binary_logloss: 0.562132
# [81]	valid_0's binary_logloss: 0.561743	valid_0's binary_logloss: 0.561743
# [82]	valid_0's binary_logloss: 0.561936	valid_0's binary_logloss: 0.561936
# [83]	valid_0's binary_logloss: 0.561294	valid_0's binary_logloss: 0.561294
# [84]	valid_0's binary_logloss: 0.56331	valid_0's binary_logloss: 0.56331
# [85]	valid_0's binary_logloss: 0.564727	valid_0's binary_logloss: 0.564727
# [86]	valid_0's binary_logloss: 0.568022	valid_0's binary_logloss: 0.568022
# [87]	valid_0's binary_logloss: 0.568659	valid_0's binary_logloss: 0.568659
# [88]	valid_0's binary_logloss: 0.568308	valid_0's binary_logloss: 0.568308
# [89]	valid_0's binary_logloss: 0.573636	valid_0's binary_logloss: 0.573636
# [90]	valid_0's binary_logloss: 0.575765	valid_0's binary_logloss: 0.575765
# [91]	valid_0's binary_logloss: 0.575585	valid_0's binary_logloss: 0.575585
# [92]	valid_0's binary_logloss: 0.575979	valid_0's binary_logloss: 0.575979
# [93]	valid_0's binary_logloss: 0.58471	valid_0's binary_logloss: 0.58471
# [94]	valid_0's binary_logloss: 0.587333	valid_0's binary_logloss: 0.587333
# [95]	valid_0's binary_logloss: 0.58932	valid_0's binary_logloss: 0.58932
# [96]	valid_0's binary_logloss: 0.589177	valid_0's binary_logloss: 0.589177
# [97]	valid_0's binary_logloss: 0.6109	valid_0's binary_logloss: 0.6109
# [98]	valid_0's binary_logloss: 0.611219	valid_0's binary_logloss: 0.611219
# [99]	valid_0's binary_logloss: 0.615365	valid_0's binary_logloss: 0.615365
# [100]	valid_0's binary_logloss: 0.619813	valid_0's binary_logloss: 0.619813
# [101]	valid_0's binary_logloss: 0.621949	valid_0's binary_logloss: 0.621949
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.214418	valid_0's binary_logloss: 0.214418
# 0.0
# [1]	valid_0's binary_logloss: 0.219866	valid_0's binary_logloss: 0.219866
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.220984	valid_0's binary_logloss: 0.220984
# [3]	valid_0's binary_logloss: 0.230181	valid_0's binary_logloss: 0.230181
# [4]	valid_0's binary_logloss: 0.241343	valid_0's binary_logloss: 0.241343
# [5]	valid_0's binary_logloss: 0.249181	valid_0's binary_logloss: 0.249181
# [6]	valid_0's binary_logloss: 0.257707	valid_0's binary_logloss: 0.257707
# [7]	valid_0's binary_logloss: 0.282742	valid_0's binary_logloss: 0.282742
# [8]	valid_0's binary_logloss: 0.286957	valid_0's binary_logloss: 0.286957
# [9]	valid_0's binary_logloss: 0.299939	valid_0's binary_logloss: 0.299939
# [10]	valid_0's binary_logloss: 0.303163	valid_0's binary_logloss: 0.303163
# [11]	valid_0's binary_logloss: 0.303628	valid_0's binary_logloss: 0.303628
# [12]	valid_0's binary_logloss: 0.306727	valid_0's binary_logloss: 0.306727
# [13]	valid_0's binary_logloss: 0.307995	valid_0's binary_logloss: 0.307995
# [14]	valid_0's binary_logloss: 0.313415	valid_0's binary_logloss: 0.313415
# [15]	valid_0's binary_logloss: 0.315426	valid_0's binary_logloss: 0.315426
# [16]	valid_0's binary_logloss: 0.316385	valid_0's binary_logloss: 0.316385
# [17]	valid_0's binary_logloss: 0.320006	valid_0's binary_logloss: 0.320006
# [18]	valid_0's binary_logloss: 0.323756	valid_0's binary_logloss: 0.323756
# [19]	valid_0's binary_logloss: 0.327047	valid_0's binary_logloss: 0.327047
# [20]	valid_0's binary_logloss: 0.32768	valid_0's binary_logloss: 0.32768
# [21]	valid_0's binary_logloss: 0.330992	valid_0's binary_logloss: 0.330992
# [22]	valid_0's binary_logloss: 0.331988	valid_0's binary_logloss: 0.331988
# [23]	valid_0's binary_logloss: 0.336302	valid_0's binary_logloss: 0.336302
# [24]	valid_0's binary_logloss: 0.343888	valid_0's binary_logloss: 0.343888
# [25]	valid_0's binary_logloss: 0.352226	valid_0's binary_logloss: 0.352226
# [26]	valid_0's binary_logloss: 0.351946	valid_0's binary_logloss: 0.351946
# [27]	valid_0's binary_logloss: 0.362242	valid_0's binary_logloss: 0.362242
# [28]	valid_0's binary_logloss: 0.366345	valid_0's binary_logloss: 0.366345
# [29]	valid_0's binary_logloss: 0.373934	valid_0's binary_logloss: 0.373934
# [30]	valid_0's binary_logloss: 0.374393	valid_0's binary_logloss: 0.374393
# [31]	valid_0's binary_logloss: 0.377993	valid_0's binary_logloss: 0.377993
# [32]	valid_0's binary_logloss: 0.378031	valid_0's binary_logloss: 0.378031
# [33]	valid_0's binary_logloss: 0.394681	valid_0's binary_logloss: 0.394681
# [34]	valid_0's binary_logloss: 0.399487	valid_0's binary_logloss: 0.399487
# [35]	valid_0's binary_logloss: 0.401773	valid_0's binary_logloss: 0.401773
# [36]	valid_0's binary_logloss: 0.407226	valid_0's binary_logloss: 0.407226
# [37]	valid_0's binary_logloss: 0.410656	valid_0's binary_logloss: 0.410656
# [38]	valid_0's binary_logloss: 0.41484	valid_0's binary_logloss: 0.41484
# [39]	valid_0's binary_logloss: 0.422199	valid_0's binary_logloss: 0.422199
# [40]	valid_0's binary_logloss: 0.428533	valid_0's binary_logloss: 0.428533
# [41]	valid_0's binary_logloss: 0.431749	valid_0's binary_logloss: 0.431749
# [42]	valid_0's binary_logloss: 0.444433	valid_0's binary_logloss: 0.444433
# [43]	valid_0's binary_logloss: 0.445282	valid_0's binary_logloss: 0.445282
# [44]	valid_0's binary_logloss: 0.444636	valid_0's binary_logloss: 0.444636
# [45]	valid_0's binary_logloss: 0.450813	valid_0's binary_logloss: 0.450813
# [46]	valid_0's binary_logloss: 0.458284	valid_0's binary_logloss: 0.458284
# [47]	valid_0's binary_logloss: 0.461847	valid_0's binary_logloss: 0.461847
# [48]	valid_0's binary_logloss: 0.462771	valid_0's binary_logloss: 0.462771
# [49]	valid_0's binary_logloss: 0.46347	valid_0's binary_logloss: 0.46347
# [50]	valid_0's binary_logloss: 0.529881	valid_0's binary_logloss: 0.529881
# [51]	valid_0's binary_logloss: 0.531116	valid_0's binary_logloss: 0.531116
# [52]	valid_0's binary_logloss: 0.532689	valid_0's binary_logloss: 0.532689
# [53]	valid_0's binary_logloss: 0.544935	valid_0's binary_logloss: 0.544935
# [54]	valid_0's binary_logloss: 0.545791	valid_0's binary_logloss: 0.545791
# [55]	valid_0's binary_logloss: 0.545948	valid_0's binary_logloss: 0.545948
# [56]	valid_0's binary_logloss: 0.547209	valid_0's binary_logloss: 0.547209
# [57]	valid_0's binary_logloss: 0.547148	valid_0's binary_logloss: 0.547148
# [58]	valid_0's binary_logloss: 0.565497	valid_0's binary_logloss: 0.565497
# [59]	valid_0's binary_logloss: 0.568267	valid_0's binary_logloss: 0.568267
# [60]	valid_0's binary_logloss: 0.723466	valid_0's binary_logloss: 0.723466
# [61]	valid_0's binary_logloss: 0.728378	valid_0's binary_logloss: 0.728378
# [62]	valid_0's binary_logloss: 0.732294	valid_0's binary_logloss: 0.732294
# [63]	valid_0's binary_logloss: 0.735732	valid_0's binary_logloss: 0.735732
# [64]	valid_0's binary_logloss: 0.740279	valid_0's binary_logloss: 0.740279
# [65]	valid_0's binary_logloss: 0.740328	valid_0's binary_logloss: 0.740328
# [66]	valid_0's binary_logloss: 0.749142	valid_0's binary_logloss: 0.749142
# [67]	valid_0's binary_logloss: 0.750714	valid_0's binary_logloss: 0.750714
# [68]	valid_0's binary_logloss: 0.752351	valid_0's binary_logloss: 0.752351
# [69]	valid_0's binary_logloss: 0.752267	valid_0's binary_logloss: 0.752267
# [70]	valid_0's binary_logloss: 0.764142	valid_0's binary_logloss: 0.764142
# [71]	valid_0's binary_logloss: 0.767455	valid_0's binary_logloss: 0.767455
# [72]	valid_0's binary_logloss: 0.770033	valid_0's binary_logloss: 0.770033
# [73]	valid_0's binary_logloss: 0.769773	valid_0's binary_logloss: 0.769773
# [74]	valid_0's binary_logloss: 0.773749	valid_0's binary_logloss: 0.773749
# [75]	valid_0's binary_logloss: 0.774845	valid_0's binary_logloss: 0.774845
# [76]	valid_0's binary_logloss: 0.778703	valid_0's binary_logloss: 0.778703
# [77]	valid_0's binary_logloss: 0.797633	valid_0's binary_logloss: 0.797633
# [78]	valid_0's binary_logloss: 0.807413	valid_0's binary_logloss: 0.807413
# [79]	valid_0's binary_logloss: 0.808962	valid_0's binary_logloss: 0.808962
# [80]	valid_0's binary_logloss: 0.814547	valid_0's binary_logloss: 0.814547
# [81]	valid_0's binary_logloss: 0.8181	valid_0's binary_logloss: 0.8181
# [82]	valid_0's binary_logloss: 0.823002	valid_0's binary_logloss: 0.823002
# [83]	valid_0's binary_logloss: 0.826171	valid_0's binary_logloss: 0.826171
# [84]	valid_0's binary_logloss: 0.830609	valid_0's binary_logloss: 0.830609
# [85]	valid_0's binary_logloss: 0.831443	valid_0's binary_logloss: 0.831443
# [86]	valid_0's binary_logloss: 0.831789	valid_0's binary_logloss: 0.831789
# [87]	valid_0's binary_logloss: 0.831541	valid_0's binary_logloss: 0.831541
# [88]	valid_0's binary_logloss: 0.836407	valid_0's binary_logloss: 0.836407
# [89]	valid_0's binary_logloss: 0.837654	valid_0's binary_logloss: 0.837654
# [90]	valid_0's binary_logloss: 0.84594	valid_0's binary_logloss: 0.84594
# [91]	valid_0's binary_logloss: 0.849343	valid_0's binary_logloss: 0.849343
# [92]	valid_0's binary_logloss: 0.849683	valid_0's binary_logloss: 0.849683
# [93]	valid_0's binary_logloss: 0.865329	valid_0's binary_logloss: 0.865329
# [94]	valid_0's binary_logloss: 0.865391	valid_0's binary_logloss: 0.865391
# [95]	valid_0's binary_logloss: 0.871522	valid_0's binary_logloss: 0.871522
# [96]	valid_0's binary_logloss: 0.877165	valid_0's binary_logloss: 0.877165
# [97]	valid_0's binary_logloss: 0.880434	valid_0's binary_logloss: 0.880434
# [98]	valid_0's binary_logloss: 0.88025	valid_0's binary_logloss: 0.88025
# [99]	valid_0's binary_logloss: 0.880018	valid_0's binary_logloss: 0.880018
# [100]	valid_0's binary_logloss: 0.879928	valid_0's binary_logloss: 0.879928
# [101]	valid_0's binary_logloss: 0.898101	valid_0's binary_logloss: 0.898101
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.219866	valid_0's binary_logloss: 0.219866
# 0.0
# [1]	valid_0's binary_logloss: 0.236269	valid_0's binary_logloss: 0.236269
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.241927	valid_0's binary_logloss: 0.241927
# [3]	valid_0's binary_logloss: 0.248998	valid_0's binary_logloss: 0.248998
# [4]	valid_0's binary_logloss: 0.256383	valid_0's binary_logloss: 0.256383
# [5]	valid_0's binary_logloss: 0.2563	valid_0's binary_logloss: 0.2563
# [6]	valid_0's binary_logloss: 0.258434	valid_0's binary_logloss: 0.258434
# [7]	valid_0's binary_logloss: 0.261238	valid_0's binary_logloss: 0.261238
# [8]	valid_0's binary_logloss: 0.263536	valid_0's binary_logloss: 0.263536
# [9]	valid_0's binary_logloss: 0.265746	valid_0's binary_logloss: 0.265746
# [10]	valid_0's binary_logloss: 0.264949	valid_0's binary_logloss: 0.264949
# [11]	valid_0's binary_logloss: 0.280284	valid_0's binary_logloss: 0.280284
# [12]	valid_0's binary_logloss: 0.278898	valid_0's binary_logloss: 0.278898
# [13]	valid_0's binary_logloss: 0.2775	valid_0's binary_logloss: 0.2775
# [14]	valid_0's binary_logloss: 0.279813	valid_0's binary_logloss: 0.279813
# [15]	valid_0's binary_logloss: 0.296232	valid_0's binary_logloss: 0.296232
# [16]	valid_0's binary_logloss: 0.296915	valid_0's binary_logloss: 0.296915
# [17]	valid_0's binary_logloss: 0.303982	valid_0's binary_logloss: 0.303982
# [18]	valid_0's binary_logloss: 0.308436	valid_0's binary_logloss: 0.308436
# [19]	valid_0's binary_logloss: 0.307537	valid_0's binary_logloss: 0.307537
# [20]	valid_0's binary_logloss: 0.30816	valid_0's binary_logloss: 0.30816
# [21]	valid_0's binary_logloss: 0.310283	valid_0's binary_logloss: 0.310283
# [22]	valid_0's binary_logloss: 0.309008	valid_0's binary_logloss: 0.309008
# [23]	valid_0's binary_logloss: 0.309002	valid_0's binary_logloss: 0.309002
# [24]	valid_0's binary_logloss: 0.325216	valid_0's binary_logloss: 0.325216
# [25]	valid_0's binary_logloss: 0.370001	valid_0's binary_logloss: 0.370001
# [26]	valid_0's binary_logloss: 0.373972	valid_0's binary_logloss: 0.373972
# [27]	valid_0's binary_logloss: 0.376064	valid_0's binary_logloss: 0.376064
# [28]	valid_0's binary_logloss: 0.375432	valid_0's binary_logloss: 0.375432
# [29]	valid_0's binary_logloss: 0.377953	valid_0's binary_logloss: 0.377953
# [30]	valid_0's binary_logloss: 0.396361	valid_0's binary_logloss: 0.396361
# [31]	valid_0's binary_logloss: 0.394983	valid_0's binary_logloss: 0.394983
# [32]	valid_0's binary_logloss: 0.394142	valid_0's binary_logloss: 0.394142
# [33]	valid_0's binary_logloss: 0.3949	valid_0's binary_logloss: 0.3949
# [34]	valid_0's binary_logloss: 0.393618	valid_0's binary_logloss: 0.393618
# [35]	valid_0's binary_logloss: 0.416333	valid_0's binary_logloss: 0.416333
# [36]	valid_0's binary_logloss: 0.415032	valid_0's binary_logloss: 0.415032
# [37]	valid_0's binary_logloss: 0.416602	valid_0's binary_logloss: 0.416602
# [38]	valid_0's binary_logloss: 0.417005	valid_0's binary_logloss: 0.417005
# [39]	valid_0's binary_logloss: 0.416889	valid_0's binary_logloss: 0.416889
# [40]	valid_0's binary_logloss: 0.417433	valid_0's binary_logloss: 0.417433
# [41]	valid_0's binary_logloss: 0.417451	valid_0's binary_logloss: 0.417451
# [42]	valid_0's binary_logloss: 0.426413	valid_0's binary_logloss: 0.426413
# [43]	valid_0's binary_logloss: 0.434726	valid_0's binary_logloss: 0.434726
# [44]	valid_0's binary_logloss: 0.440579	valid_0's binary_logloss: 0.440579
# [45]	valid_0's binary_logloss: 0.443132	valid_0's binary_logloss: 0.443132
# [46]	valid_0's binary_logloss: 0.443601	valid_0's binary_logloss: 0.443601
# [47]	valid_0's binary_logloss: 0.443854	valid_0's binary_logloss: 0.443854
# [48]	valid_0's binary_logloss: 0.453579	valid_0's binary_logloss: 0.453579
# [49]	valid_0's binary_logloss: 0.452945	valid_0's binary_logloss: 0.452945
# [50]	valid_0's binary_logloss: 0.457812	valid_0's binary_logloss: 0.457812
# [51]	valid_0's binary_logloss: 0.457894	valid_0's binary_logloss: 0.457894
# [52]	valid_0's binary_logloss: 0.464402	valid_0's binary_logloss: 0.464402
# [53]	valid_0's binary_logloss: 0.467164	valid_0's binary_logloss: 0.467164
# [54]	valid_0's binary_logloss: 0.468285	valid_0's binary_logloss: 0.468285
# [55]	valid_0's binary_logloss: 0.468187	valid_0's binary_logloss: 0.468187
# [56]	valid_0's binary_logloss: 0.472687	valid_0's binary_logloss: 0.472687
# [57]	valid_0's binary_logloss: 0.473119	valid_0's binary_logloss: 0.473119
# [58]	valid_0's binary_logloss: 0.481583	valid_0's binary_logloss: 0.481583
# [59]	valid_0's binary_logloss: 0.48707	valid_0's binary_logloss: 0.48707
# [60]	valid_0's binary_logloss: 0.48685	valid_0's binary_logloss: 0.48685
# [61]	valid_0's binary_logloss: 0.488574	valid_0's binary_logloss: 0.488574
# [62]	valid_0's binary_logloss: 0.497549	valid_0's binary_logloss: 0.497549
# [63]	valid_0's binary_logloss: 0.501941	valid_0's binary_logloss: 0.501941
# [64]	valid_0's binary_logloss: 0.516661	valid_0's binary_logloss: 0.516661
# [65]	valid_0's binary_logloss: 0.516902	valid_0's binary_logloss: 0.516902
# [66]	valid_0's binary_logloss: 0.518803	valid_0's binary_logloss: 0.518803
# [67]	valid_0's binary_logloss: 0.518804	valid_0's binary_logloss: 0.518804
# [68]	valid_0's binary_logloss: 0.534614	valid_0's binary_logloss: 0.534614
# [69]	valid_0's binary_logloss: 0.53758	valid_0's binary_logloss: 0.53758
# [70]	valid_0's binary_logloss: 0.538352	valid_0's binary_logloss: 0.538352
# [71]	valid_0's binary_logloss: 0.540712	valid_0's binary_logloss: 0.540712
# [72]	valid_0's binary_logloss: 0.54053	valid_0's binary_logloss: 0.54053
# [73]	valid_0's binary_logloss: 0.556686	valid_0's binary_logloss: 0.556686
# [74]	valid_0's binary_logloss: 0.572136	valid_0's binary_logloss: 0.572136
# [75]	valid_0's binary_logloss: 0.571509	valid_0's binary_logloss: 0.571509
# [76]	valid_0's binary_logloss: 0.573289	valid_0's binary_logloss: 0.573289
# [77]	valid_0's binary_logloss: 0.58908	valid_0's binary_logloss: 0.58908
# [78]	valid_0's binary_logloss: 0.590425	valid_0's binary_logloss: 0.590425
# [79]	valid_0's binary_logloss: 0.589974	valid_0's binary_logloss: 0.589974
# [80]	valid_0's binary_logloss: 0.589581	valid_0's binary_logloss: 0.589581
# [81]	valid_0's binary_logloss: 0.592257	valid_0's binary_logloss: 0.592257
# [82]	valid_0's binary_logloss: 0.598107	valid_0's binary_logloss: 0.598107
# [83]	valid_0's binary_logloss: 0.598102	valid_0's binary_logloss: 0.598102
# [84]	valid_0's binary_logloss: 0.598601	valid_0's binary_logloss: 0.598601
# [85]	valid_0's binary_logloss: 0.602355	valid_0's binary_logloss: 0.602355
# [86]	valid_0's binary_logloss: 0.601679	valid_0's binary_logloss: 0.601679
# [87]	valid_0's binary_logloss: 0.603476	valid_0's binary_logloss: 0.603476
# [88]	valid_0's binary_logloss: 0.604155	valid_0's binary_logloss: 0.604155
# [89]	valid_0's binary_logloss: 0.604008	valid_0's binary_logloss: 0.604008
# [90]	valid_0's binary_logloss: 0.606649	valid_0's binary_logloss: 0.606649
# [91]	valid_0's binary_logloss: 0.617403	valid_0's binary_logloss: 0.617403
# [92]	valid_0's binary_logloss: 0.617149	valid_0's binary_logloss: 0.617149
# [93]	valid_0's binary_logloss: 0.617766	valid_0's binary_logloss: 0.617766
# [94]	valid_0's binary_logloss: 0.620357	valid_0's binary_logloss: 0.620357
# [95]	valid_0's binary_logloss: 0.621274	valid_0's binary_logloss: 0.621274
# [96]	valid_0's binary_logloss: 0.630061	valid_0's binary_logloss: 0.630061
# [97]	valid_0's binary_logloss: 0.632296	valid_0's binary_logloss: 0.632296
# [98]	valid_0's binary_logloss: 0.633918	valid_0's binary_logloss: 0.633918
# [99]	valid_0's binary_logloss: 0.635589	valid_0's binary_logloss: 0.635589
# [100]	valid_0's binary_logloss: 0.635506	valid_0's binary_logloss: 0.635506
# [101]	valid_0's binary_logloss: 0.636809	valid_0's binary_logloss: 0.636809
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.236269	valid_0's binary_logloss: 0.236269
# 0.0

# %%
y_pro = pd.DataFrame(model.predict_proba(test1))

# %%
y_pro
# Out:
#                 0         1
# 0        0.938931  0.061069
# 1        0.948999  0.051001
# 2        0.941070  0.058930
# 3        0.948999  0.051001
# 4        0.948565  0.051435
# ...           ...       ...
# 3242639  0.948565  0.051435
# 3242640  0.950470  0.049530
# 3242641  0.950470  0.049530
# 3242642  0.950470  0.049530
# 3242643  0.950470  0.049530
#
# [3242644 rows x 2 columns]

# %%
train['is_applied'].sum()/train['is_applied'].count()
# Out:
# 0.05400555471007496

# %%
y_pro['is_applied'] = 0
y_pro.loc[y_pro[1]>0.1, 'is_applied']=1

# %%
y_pro
# Out:
#                 0         1  is_applied
# 0        0.938931  0.061069           0
# 1        0.948999  0.051001           0
# 2        0.941070  0.058930           0
# 3        0.948999  0.051001           0
# 4        0.948565  0.051435           0
# ...           ...       ...         ...
# 3242639  0.948565  0.051435           0
# 3242640  0.950470  0.049530           0
# 3242641  0.950470  0.049530           0
# 3242642  0.950470  0.049530           0
# 3242643  0.950470  0.049530           0
#
# [3242644 rows x 3 columns]

# %%
test['is_applied']=y_pro['is_applied']

# %%
# 답안 파일 불러오기
file = pd.read_csv("/content/gdrive/MyDrive/데이터분석분야_퓨처스부문_평가데이터.csv")
file.drop('is_applied', axis=1, inplace=True)

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3255194 entries, 0 to 3255193
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   application_id  int64
#  1   product_id      int64
#  2   is_applied      float64
# dtypes: float64(1), int64(2)
# memory usage: 74.5 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3242644 entries, 0 to 3242643
# Data columns (total 34 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   product_id                           int64
#  1   product_count                        int64
#  2   pro_apply_rate                       float64
#  3   bank_id                              float64
#  4   bank_count                           float64
#  5   bank_product                         float64
#  6   apply_rate_bank                      float64
#  7   application_id                       float64
#  8   user_id                              float64
#  9   insert_time                          object
#  10  credit_score                         float64
#  11  yearly_income                        float64
#  12  income_type                          object
#  13  company_enter_month                  object
#  14  employment_type                      object
#  15  houseown_type                        object
#  16  desired_amount                       float64
#  17  purpose                              object
#  18  personal_rehabilitation_yn           float64
#  19  personal_rehabilitation_complete_yn  float64
#  20  existing_loan_cnt                    float64
#  21  existing_loan_amt                    float64
#  22  NA_count                             float64
#  23  gender                               float64
#  24  birth_year                           float64
#  25  age                                  float64
#  26  company_month                        float64
#  27  lotloan                              float64
#  28  loanapply_insert_time                object
#  29  loan_limit                           float64
#  30  loan_rate                            float64
#  31  is_applied                           int64
#  32  pre_bank_rate                        float64
#  33  desired_rate                         float64
# dtypes: float64(24), int64(3), object(7)
# memory usage: 865.9+ MB

# %% [markdown]
# - train data 파생변수 합치기

# %%
com2 =  pd.merge(file, test[['application_id','product_id', 'is_applied']], on=['application_id','product_id'], how='left')

# %%
com2
# Out:
#          application_id  product_id  is_applied
# 0                     4         220         0.0
# 1                     4         191         0.0
# 2                     8          29         1.0
# 3                     8         159         0.0
# 4                     8          85         1.0
# ...                 ...         ...         ...
# 3255189         2167778         258         0.0
# 3255190         2167791          29         0.0
# 3255191         2167822         149         0.0
# 3255192         2167822         157         0.0
# 3255193         2167822          65         0.0
#
# [3255194 rows x 3 columns]

# %%
com2
# Out:
#          application_id  product_id  is_applied
# 0                     4         220         0.0
# 1                     4         191         0.0
# 2                     8          29         1.0
# 3                     8         159         0.0
# 4                     8          85         1.0
# ...                 ...         ...         ...
# 3255189         2167778         258         0.0
# 3255190         2167791          29         0.0
# 3255191         2167822         149         0.0
# 3255192         2167822         157         0.0
# 3255193         2167822          65         0.0
#
# [3255194 rows x 3 columns]

# %%
com2.loc[com2['is_applied'].isna(), 'is_applied']=0

# %%
com2.isna().sum()
# Out:
# application_id    0
# product_id        0
# is_applied        0
# dtype: int64

# %%
com2.to_csv('./결과제출.csv')
